# %%
import my_util as my_util
import cluster_skill_helpers as cluster_skill_helpers
from cluster_skill_helpers import *

# %%
HOME_DIR = 'd:/larc_projects/job_analytics/'; DATA_DIR = HOME_DIR + 'data/clean/'
RES_DIR = HOME_DIR + 'results/'; 
SKILL_DAT = DATA_DIR + 'skill_cluster/'; SKILL_RES = RES_DIR + 'skill_cluster/new/'

# %%
df = pd.read_csv(SKILL_DAT + 'doc_index.csv')

# %% [markdown]
# ### Removing reposts

# %%
df = df.sort_values(['employer_name', 'doc'])
print('# posts bf filtering dups: %d' %df.shape[0])

# %%
df.head(10)

# %%
df = df.drop_duplicates(['employer_name', 'doc'])
print('# posts after filtering dups: %d' %df.shape[0])

# %%
df.head(10)

# %%
df = df.reset_index()
df.head()

# %%
df.to_csv(SKILL_DAT + 'uniq_doc_index.csv', index=False)

# %% [markdown]
# A careful check also reveals a renaming of job title (from Marine Superintendent to Fleet Manager, employer: "K" LINE LOGISTICS SINGAPORE), though the posts are the same. This is also interesting and may need further analysis later. However, we first need to re-plot cluster distributions again to see if we really get rid of dups.

# %%
df = pd.read_csv(SKILL_DAT + 'uniq_doc_index.csv')
df = df.set_index('index')

# %%
with(open(LDA_DIR + 'doc_topic_distr.mtx', 'r')) as f:
    doc_topic_distr = mmread(f)

# %%
# Global settings for all cluster plots
abbv_clusters = ['FIN', 'HWR', 'SCI', 'PROD', 'CON', 'LEG', 'CUS', 'LOG', 'MKT', 'DEV', 'MAN', 'HOS', 'AUD', 'COM', 'HR']
x = range(1, 16); labels = abbv_clusters

# %%
def getPosts2Check(job_title, industry, n_pair=10):
    sub_df = df[(df['title'] == job_title) & (df['industry'] == industry)]
    # Drop duplicated posts due to reposting
    
    scores = calScore(sub_df, doc_topic_distr)
    scores = scores.query('sim_score < 1').sort_values('sim_score', ascending=False)

    k_pairs = scores.head(n_pair)
    
    ids2check = np.unique(list(k_pairs['job_id1']) + list(k_pairs['job_id2']))
    print('# posts to check: %d' %len(ids2check))

    posts2check = sub_df[sub_df['job_id'].isin(ids2check)]
    return posts2check.sort_values('employer_name')

#     return k_pairs

# %%
def plotClusterDists(posts, figsize):
    n_post = posts.shape[0]
    fig, axarr = plt.subplots(n_post, sharex=True, figsize=figsize)

    for r in range(n_post):
        plt.subplot(n_post, 1, r+1)
        plotClusterDistAtRow(r, posts, doc_topic_distr)
        # Show ylabel at the middle
        if r==(n_post/2 - 1): 
            plt.ylabel('Probability', fontsize=24)

    ## Fine tune the fig    
    fig.subplots_adjust(hspace=.5)

    # Hide xticks on all subplots except the last one
    hide_xticks(fig)

    # Provide xtick labels only for the last subplot
    plt.xticks(x, labels, rotation=45)
    # Show xlabel only at the last subplot    
    plt.xlabel('Skill Clusters', fontsize=20)
    return fig

# %%
posts2check = getPosts2Check(job_title="Software Engineer", industry="Financial and Insurance Activities", n_pair=5)
fig = plotClusterDists(posts2check, figsize=(6, 10))
# plt.savefig(LDA_DIR + 'fig/se_in_fin2.pdf')
plt.show(); plt.close()
# Out:
# Computing pair similarity scores among 31 job posts,
# each post is compared with subseq posts...
# 	 0 posts and counting...
# 	 10 posts and counting...
# 	 20 posts and counting...
# Done after 0.6s
# # posts to check: 8

# %% [markdown]
# __Duplications seem still exist!__ Let us examine further.
#
# + Sample posts for SE:

# %%
sample_employers = ["Capital Match Holdings Pte. Ltd.", "Comfortdelgro Corporation Limited", "Fujitsu Asia Pte Ltd", 
             "Millennium Capital Management (Singapore) Pte. Ltd."]

sample_employers = map(str.upper, sample_employers)
sample_se_posts = df[(df.employer_name.isin(sample_employers)) & (df.title == "Software Engineer")]
se_fig = plotClusterDists(sample_se_posts)

plt.show(); plt.close()

# %%
dups = df[(df.employer_name.isin(sample_employers)) & (df.title == "Software Engineer")]
dups = dups.sort_values('employer_name')

# %% [markdown]
# + Save duplicated and unique versions to files for further analysis:

# %%
dups.to_csv(RES_DIR + 'tmp/se_dups.csv', index=False)
dups.drop_duplicates(['doc']).to_csv(RES_DIR + 'tmp/se_no_dups2.csv', index=False)

# %% [markdown]
# By reading the job posts of Capital Match Holdings, we found that they are actually different. However, the differences in their contents are __subtle__. Cluster distribution of the last post is a bit different from the first two because the last one has no salary detail while the first two provide salary and equity. A closer look at the skill sets in these posts reveals:
#
# + skill set of the first 2 posts = skill set of the last post + {equity}
# + salary in 1st post is more than salary in 2nd post (4K vs. 3K)

# %% [markdown]
# + Other examples of suspicious dups:

# %%
se_in_infocom = getPosts2Check(job_title='Software Engineer', industry='Information and Communications')

# %%
fig = plotClusterDists(se_in_infocom)
plt.savefig(LDA_DIR + 'fig/se_in_infocom2.pdf')
plt.show(); plt.close()

# %% [markdown]
# + Sample posts for Administrative Assistant:

# %%
posts = getPosts2Check(job_title="Administrative Assistant", industry="Financial and Insurance Activities", n_pair=5)

# %%
fig = plotClusterDists(posts, figsize=(6, 12))
# plt.savefig(LDA_DIR + 'fig/admin_in_fin.jpg')
plt.show(); plt.close()

# %%
# Manager
posts = getPosts2Check(job_title="Manager", industry="Financial and Insurance Activities", n_pair=5)

# %%
fig = plotClusterDists(posts, figsize=(6, 12))
plt.savefig(LDA_DIR + 'fig/man_in_fin.jpg')
plt.savefig(LDA_DIR + 'fig/man_in_fin.pdf')
plt.show(); plt.close()

# %% [markdown]
# These example tell us that we should also filter out the posts with are almost identical. Such posts can be detected based on the set of common skills (Jaccard similarity) as in the next section.

# %% [markdown]
# ### Detecting Almost-Identical Posts by Common Skills
#
# In this section we use Jaccard similarity to detect posts that are almost-identical. We expect that such posts usually come from the same company. Thus, we first analyze the posts under the same company.

# %%
cmh = df[df.employer_name == str.upper("Capital Match Holdings Pte. Ltd.")]
pairwiseJacSim(df=cmh)

# %% [markdown]
# This example confirms that posts under the same company can be very similar, the percentage of overlapping skills can be more than 90%. We want to remove such pairs of posts as they can be the reason consistency score are over-estimated.
#
# The filtering process for a given DF of posts is follows.
# + Init an empty list _keep_
# + Compute Jaccard similarities of the first post with the remaining posts
# + Add the 1st post to _keep_ and remove it from _remain_ as well as any post which is too similar with the 1st post
# + Repeat the process until no more post left in _remain_.

# %%
def filterSimPosts(i, employer='Capital Match Holdings Pte. Ltd.', sim_thres=.9):
    
    def doFilter(df):
        keep, remain = [], df
        t0 = time()
        # While there are at least 2 posts then we need to check
        while (remain.shape[0] >= 2):
            res = jacSim2Others(0, remain)
            
            job_id = remain.iloc[0]['job_id']
            keep.append(job_id)
            # In the remain, keep only posts that are sig. diff from post[0]
            sig_diff_posts = list(res.query('jacSim < {}'.format(sim_thres))['job_id2'])
            remain = remain[remain['job_id'].isin(sig_diff_posts)]
        
        # If only 1 post remains then we can just keep it as there are no more posts too similar to it
        if (remain.shape[0] == 1):
            keep.append(remain.iloc[0]['job_id'])
        
        print('\t done after {}s'.format(round(time()-t0, 1)))
        return df[df['job_id'].isin(keep)]
    
    
    sub_df = df[df.employer_name == employer.upper()]; n_post = sub_df.shape[0]
    #         if (i % 100 == 0):
    print('\t{}, {}, {} posts'.format(i, employer, n_post))
    return doFilter(sub_df)

# %%
tmp = filterSimPosts(0, employer='Capital Match Holdings Pte. Ltd.', sim_thres=.9)
pairwiseJacSim(tmp)
# Out:
# 	0, Capital Match Holdings Pte. Ltd., 5 posts, 0.0s elapsed
# Computing pairwise Jaccard similarities among 3 job posts,
# each post is compared against its subseq posts...
# Done after 0.0s
#                            employer  intersection_size  jacSim  \
# 0  CAPITAL MATCH HOLDINGS PTE. LTD.                  7    0.44
# 1  CAPITAL MATCH HOLDINGS PTE. LTD.                  5    0.29
# 2  CAPITAL MATCH HOLDINGS PTE. LTD.                  5    0.28
#
#             job_id1           job_id2  \
# 0  JOB-2015-0198405  JOB-2015-0198229
# 1  JOB-2015-0198405  JOB-2015-0256490
# 2  JOB-2015-0198229  JOB-2015-0256490
#
#                                              skills1  \
# 0  {referrals, investors, credit, institutional i...
# 1  {referrals, investors, credit, institutional i...
# 2  {web, investors, institutional investors, capi...
#
#                                              skills2  union_size
# 0  {web, investors, institutional investors, capi...          16
# 1  {investors, processing, competitive, banking, ...          17
# 2  {investors, processing, competitive, banking, ...          18

# %%
tmp = filterSimPosts(1, employer='Apar Technologies Pte. Ltd.', sim_thres=.9)
pairwiseJacSim(tmp)

# %%
by_employer = df.groupby('employer_name').agg({'job_id': 'nunique'})
by_employer = by_employer.add_prefix('n_').reset_index()

# by_employer.n_job_id.describe().round(1)

by_employer = by_employer.sort_values('n_job_id')
employers = list(by_employer.query('n_job_id >= 2')['employer_name'])
len(employers)
# Out:
# 6838

# %%
print('Filtering too similar posts in {} companies...'.format(len(employers)))
# Out:
# Filtering too similar posts in 6838 companies...

# %%
def filterPosts4Employers(start=0, end=100):
    t0 = time()
    frames = [filterSimPosts(i+start, emp, sim_thres=.9) for i, emp in enumerate(employers[start:end])]
    filtered_df = pd.concat(frames)
    print('Done after %.1fs' %(time() - t0))
    return filtered_df

# %%
filtered_df_1 = filterPosts4Employers(start=0, end=3000)
# Out:
# 	0, KIARATEX EXPORTS PTE LTD, 2 posts, 0.0s elapsed
# 	100, KPS CONSTRUCTION & ENGINEERING PTE. LTD., 2 posts, 0.0s elapsed
# 	200, TANESEI TRADING PTE. LTD., 2 posts, 0.0s elapsed
# 	300, IT-GRID TECHNOLOGIES PTE. LTD., 2 posts, 0.0s elapsed
# 	400, KALTIMEX ENERGY (SINGAPORE) PTE LTD, 2 posts, 0.0s elapsed
# 	500, PRESTIGE BIOSYSTEMS PTE LTD, 2 posts, 0.0s elapsed
# 	600, ST. ANDREW'S DENTAL SURGEONS GROUP PTE. LTD., 2 posts, 0.0s elapsed
# 	700, MEGAWAY ENGINEERING & TRADING PTE LTD, 2 posts, 0.0s elapsed
# 	800, NELCO PRODUCTS PTE. LTD., 2 posts, 0.0s elapsed
# 	900, LYS ENERGY SOLUTIONS PTE. LTD., 2 posts, 0.0s elapsed
# 	1000, SINOHYDRO-SEMBCORP JOINT VENTURE, 2 posts, 0.0s elapsed
# 	1100, ELTEK POWER PTE. LTD., 2 posts, 0.0s elapsed
# 	1200, HTE (S) PTE. LTD., 2 posts, 0.0s elapsed
# 	1300, BANFF CYBER TECHNOLOGIES PTE. LTD., 2 posts, 0.0s elapsed
# 	1400, AYA FUJI INTERNATIONAL (M & E) PTE LTD, 2 posts, 0.0s elapsed
# 	1500, ESPZEN PTE. LTD., 2 posts, 0.0s elapsed
# 	1600, BRADY ENGINEERING PTE. LTD., 2 posts, 0.0s elapsed
# 	1700, ALLIANCE HEALTHCARE GROUP PTE LTD, 2 posts, 0.0s elapsed
# 	1800, C P WORLD PTE. LTD., 2 posts, 0.0s elapsed
# 	1900, SINGAPORE INSTITUTE OF MANAGEMENT, 3 posts, 0.0s elapsed
# 	2000, SOUTHERN GLOBE CORPORATION PTE. LTD., 3 posts, 0.0s elapsed
# 	2100, NET SOFTWARE TECHNOLOGY PTE. LTD., 3 posts, 0.0s elapsed
# 	2200, DELUGE FIRE PROTECTION (S.E.A.) PTE LTD, 3 posts, 0.0s elapsed
# 	2300, DAVID WOOD & ASSOCIATES PTE. LTD., 3 posts, 0.0s elapsed
# 	2400, SHEVS IFT CONSULTANTS PTE. LTD., 3 posts, 0.0s elapsed
# 	2500, COLUMBIA SHIPMANAGEMENT (SINGAPORE) PTE LTD, 3 posts, 0.0s elapsed
# 	2600, HRNET ONE PTE LTD, 3 posts, 0.0s elapsed
# 	2700, AVA INSURANCE AGENCY PTE. LTD., 3 posts, 0.0s elapsed
# 	2800, THE BANK OF NOVA SCOTIA, 3 posts, 0.0s elapsed
# 	2900, J. F. HILLEBRAND SINGAPORE PTE. LTD., 3 posts, 0.0s elapsed
# Done after 27.0s

# %%
filtered_df_2 = filterPosts4Employers(start=3000, end=5000)
# Out:
# 	3000, LIAN SIONG ALUMINIUM & TRADING PTE. LTD., 4 posts, 0.0s elapsed
# 	3100, ANIMAL RECOVERY VETERINARY CENTRE PTE. LTD., 4 posts, 0.0s elapsed
# 	3200, UHP TECHNOLOGY PTE. LTD., 4 posts, 0.0s elapsed
# 	3300, SWEE HUP ENGINEERING RESOURCES PTE LTD, 4 posts, 0.0s elapsed
# 	3400, SOCIETY FOR WINGS, 4 posts, 0.0s elapsed
# 	3500, FAGERDALA SINGAPORE PTE LTD, 4 posts, 0.0s elapsed
# 	3600, SINGAPORE SAIZERIYA PTE. LTD., 4 posts, 0.0s elapsed
# 	3700, NATIONAL HEALTHCARE GROUP PHARMACY, 4 posts, 0.0s elapsed
# 	3800, D.PBU PTE. LTD., 5 posts, 0.0s elapsed
# 	3900, GENESYS TELECOMMUNICATIONS LABORATORIES ASIA PTE LTD, 5 posts, 0.0s elapsed
# 	4000, PULSESYNC PTE. LTD., 5 posts, 0.0s elapsed
# 	4100, LOTUS ASIA TOURS PTE. LTD., 5 posts, 0.0s elapsed
# 	4200, SHOPPY PTE. LTD., 5 posts, 0.0s elapsed
# 	4300, SHIN KHAI CONSTRUCTION PTE. LTD., 6 posts, 0.0s elapsed
# 	4400, DNATA SINGAPORE PTE. LTD., 6 posts, 0.0s elapsed
# 	4500, APP SYSTEMS SERVICES PTE. LTD., 6 posts, 0.0s elapsed
# 	4600, BLUM & CO PTE LTD, 6 posts, 0.0s elapsed
# 	4700, GATEWAY TECHNOLOGIES SERVICES PTE LTD, 7 posts, 0.0s elapsed
# 	4800, SINGAPORE ASSOCIATION OF THE VISUALLY HANDICAPPED, 7 posts, 0.0s elapsed
# 	4900, GRAPHENE SERVICES PTE. LTD., 7 posts, 0.0s elapsed
# Done after 57.3s

# %%
filtered_df_3 = filterPosts4Employers(start=5000, end=6000)
# Out:
# 	5000, NOOR HOLDINGS PTE. LTD., 8 posts, 0.1s elapsed
# 	5100, YOUNG WOMEN'S CHRISTIAN ASSOCIATION OF SINGAPORE, 8 posts, 0.1s elapsed
# 	5200, TAYLOR & FRANCIS ASIA PACIFIC, 9 posts, 0.1s elapsed
# 	5300, VINTEDGE PTE LTD, 9 posts, 0.1s elapsed
# 	5400, KGI FRASER SECURITIES PTE. LTD., 10 posts, 0.1s elapsed
# 	5500, PROCTER & GAMBLE EUROPE SA SINGAPORE BRANCH, 10 posts, 0.1s elapsed
# 	5600, SPARKY ANIMATION PTE. LTD., 11 posts, 0.1s elapsed
# 	5700, SULZER CHEMTECH PTE. LTD., 12 posts, 0.1s elapsed
# 	5800, KEPPEL SEA SCAN PTE LTD, 13 posts, 0.2s elapsed
# 	5900, FIRMENICH ASIA PTE LTD, 15 posts, 0.2s elapsed
# Done after 99.0s

# %%
# Defensive save
filtered_df.to_csv(SKILL_DAT + 'filter_doc_index.csv', index=False)

# %%
filtered_df_4 = filterPosts4Employers(start=6000, end=len(employers)-5)
# Out:
# 	6000, SWISS REINSURANCE COMPANY LTD, 16 posts, 0.2s elapsed
# 	6100, LEAP NETWORKS PTE. LTD., 18 posts, 0.2s elapsed
# 	6200, JOHNSON CONTROLS HOLDING (S) PTE. LTD., 20 posts, 0.3s elapsed
# 	6300, SG REHAB PTE LTD, 24 posts, 0.2s elapsed
# 	6400, ALEXANDER MANN BPO SOLUTIONS (SINGAPORE) PTE. LTD., 29 posts, 0.6s elapsed
# 	6500, LUCASFILM ANIMATION COMPANY SINGAPORE B.V., 37 posts, 0.9s elapsed
# 	6600, PARKROYAL KITCHENER HOTEL PTE. LTD., 48 posts, 1.3s elapsed
# 	6700, ON DEMAND AGILITY SOLUTIONS PTE. LTD., 72 posts, 3.2s elapsed
# 	6800, ADECCO PERSONNEL PTE LTD, 210 posts, 27.2s elapsed
# Done after 3510.4s

# %%
filtered_df_6 = filterPosts4Employers(start=len(employers)-5, end=len(employers)-4)
# Out:
# 	6833, DBS BANK LTD., 644 posts

# %%
filtered_df_5 = filterPosts4Employers(start=len(employers)-4, end=len(employers))
# Out:
# 	6834, MACHSPEED HUMAN RESOURCES PTE. LTD., 664 posts
# 	 done after 171.1s
# 	6835, STANDARD CHARTERED BANK, 668 posts
# 	 done after 263.7s
# 	6836, NATIONAL UNIVERSITY OF SINGAPORE, 1255 posts
# 	 done after 946.2s
# 	6837, NANYANG TECHNOLOGICAL UNIVERSITY, 1292 posts
# 	 done after 928.0s
# Done after 2309.1s

# %%
filtered_df = pd.concat([filtered_df_1, filtered_df_2, filtered_df_3, filtered_df_4, filtered_df_5, filtered_df_6])
print filtered_df.shape

filtered_df = filtered_df.reset_index()
filtered_df.to_csv(SKILL_DAT + 'filter_doc_index.csv', index=False)
# Out:
# (70723, 8)

# %%
df = df.dropna()
df.to_csv(SKILL_DAT + 'uniq_doc_index.csv', index=False)

# %%
dbs = df[df.employer_name == 'DBS BANK LTD.']

# %%
dbs.iloc[541]
# dbs = dbs.drop(dbs.index[541])
# Out:
# doc              support the roll out and monitoring of best pr...
# job_id                                            JOB-2015-0147783
# title                            Information Technology Specialist
# n_skill                                                          0
# occur_skills                                                   NaN
# employer_id                                             196800306E
# employer_name                                        DBS BANK LTD.
# industry                        Financial and Insurance Activities
# Name: 99655, dtype: object

# %%
for r, skill_str in enumerate(dbs.occur_skills):
    print((r, skill_str.split()))
# Out:
# (0, ['change,documentations,processing,trends,troubleshooting,vulnerability,change', 'management,team', 'work,information', 'security', 'standards'])
# (1, ['awareness,benefits,cluster,coaching,crisis,deals,deposits,engagement,enquiries,equity,expert,feedback,investment,investments,ipo,legal,offshore,onshore,performing,probate,regulatory,revenue,risk,rules,targets,treasury,trust,wealth,asset', 'allocation,fiduciary', 'services,investment', 'products,investment', 'sales,process', 'enhancement,process', 'improvement,product', 'development,sales', 'management,structured', 'notes,unit', 'trusts,sales', 'and', 'marketing'])
# (2, ['consultant,mlc,murex,vendor,back', 'office,best', 'practices,corrective', 'actions,front', 'office,production', 'support,release', 'management,system', 'maintenance,technical', 'support,user', 'acceptance', 'testing'])
# (3, ['analytics,change,communicator,competitive,css,dashboards,deliverables,developers,driving,efficiency,flexibility,internet,optimizations,targets,trends,web,websites,business', 'units,customer', 'engagement,delivering', 'results,landing', 'pages,product', 'launches,sales', 'management,search', 'engines,online', 'user', 'experience'])
# (4, ['advisory,assurance,awareness,committees,courses,expert,levels,policy,protection,reputation,risk,sanction,sanctions,trends,compliance', 'training,senior', 'management'])
# (5, ['deliverables,performing,productivity,rollout,strength,customer', 'experience,technical', 'support'])
# (6, ['credit,director,negotiations,security,supervision,client', 'coverage,financial', 'statements,operational', 'risk', 'management,strong', 'analytical', 'skills'])
# (7, ['architectural,forecasting,infrastructure,conceptual', 'design,design', 'specifications,technical', 'architecture,technical', 'design'])
# (8, ['audit,efficiency,feedback,health,investigation,levels,performing,productivity,rates,turnaround,cash', 'handling,customer', 'satisfaction,customer', 'service,regulatory', 'compliance,security', 'audit'])
# (9, ['completion,wealth,customer', 'satisfaction,customer', 'service,investment', 'products,regulatory', 'compliance,sales', 'process,security', 'audit'])
# (10, ['accountability,culture,performing,productivity,profitability,regulatory,security,selling,internal', 'audit,service', 'delivery'])
# (11, ['accountability,culture,performing,productivity,regulatory,security,selling,targets,internal', 'audit,regulatory', 'requirements,sales', 'performance,service', 'delivery'])
# (12, ['bau,deliverables,hpqc,impact,provisioning,rollout,scheduling,service', 'delivery,testing', 'tools'])
# (13, ['accountability,acting,culture,motivation,profitability,revenue,security,selling,customer', 'satisfaction,internal', 'audit,regulatory', 'requirements,training', 'development'])
# (14, ['referrals,validation,corporate', 'insurance,value', 'proposition'])
# (15, ['aml,audit,cft,change,controls,efficiency,financing,governance,kyc,regulatory,sanctions,tax,terrorism,uat,customer', 'service,fraud', 'management,front', 'office,retail', 'banking,anti', 'money', 'laundering,operational', 'risk', 'management,user', 'acceptance', 'testing'])
# (16, ['asset,custody,efficiency,impact,levels,metrics,presentation,questionnaires,regulatory,reviews,securities,sla,transitions,trends,business', 'launch,customer', 'experience,due', 'diligence,fiduciary', 'services,global', 'markets'])
# (17, ['credit,database,reviews,sampling,tracking,administrative', 'support,credit', 'review,daily', 'operations,financial', 'data,management', 'reporting,trend', 'analysis'])
# (18, ['boost,collaboration,culture,dynamic,editorial,exercises,feedback,impact,profitability,reviews,rewards,ups,wealth,best', 'practices,brand', 'building,business', 'analytics,client', 'communication,client', 'engagement,market', 'data,private', 'banking,team', 'work'])
# (19, ['bonds,cash,custodians,entitlements,event,liaison,processing,reconciliation,rms,securities,stock,corporate', 'actions,tax', 'reporting'])
# (20, ['cash,custodians,escalation,event,liaison,processing,reconciliation,rms,securities,stock,treatment,verification,tax', 'reporting,team', 'work'])
# (21, ['audit,documentations,risk,syndicate,trends,metrics', 'reporting,risk', 'mitigation'])
# (22, ['deliverables,deployment,infrastructure,optimisation,pmo,tracking,requirements', 'gathering'])
# (23, ['automation,deployment,designing,hardware,infrastructure,java,security,application', 'development,application', 'servers,application', 'support,continuous', 'integration,data', 'protection'])
# (24, ['collateral,competitive,controlling,controls,credit,derivatives,financing,integrity,legal,margin,regulations,regulatory,risk,stress,trends,underwriting,valuation,approval', 'process,credit', 'risk,portfolio', 'risk,senior', 'management,stress', 'testing,board', 'of', 'directors'])
# (25, ['credit,proactive,reviews,scorecard,sound,targets,turnaround,uat,underwriting,credit', 'risk,risk', 'management,sme', 'banking'])
# (26, ['automation,pricing,rates,reserves,trading,upgrades,yield,project', 'implementation'])
# (27, ['automation,pricing,rates,reserves,trading,upgrades,valuation,yield,approval', 'process,project', 'implementation'])
# (28, ['administrative,policy,statistics,client', 'service,power', 'point,service', 'delivery,service', 'providers,transaction', 'processing,process', 'improvement', 'projects'])
# (29, ['asset,contract,contracts,expenses,gps,minutes,pmc,pmo,presentation,procurement,sharepoint,vendor,workshops,project', 'managers'])
# (30, ['communications,messaging,pitching,scorecard,selection,strategy,business', 'planning,digital', 'banking,operational', 'excellence,strategic', 'initiatives'])
# (31, ['administrative,collateral,consolidation,database,filing,logging,administrative', 'functions,data', 'sheets,user', 'acceptance', 'testing'])
# (32, ['administrative,collateral,consolidation,database,filing,logging,administrative', 'functions,data', 'sheets,user', 'acceptance', 'testing'])
# (33, ['bancassurance,campaigns,sound,product', 'development'])
# (34, ['credit,database,workstream,coordinate', 'meetings,data', 'governance'])
# (35, ['commercial,digital,fit,negotiations,sme,business', 'strategy,sme', 'banking'])
# (36, ['audit,collections,infrastructure,risk,best', 'practices,continuous', 'improvement,gap', 'analysis,operation', 'management,process', 'improvement'])
# (37, ['administration,emergency,engagement,fax,hardware,inventory,liaison,property,security'])
# (38, ['cash,liquidity,traders,trading,interest', 'rates'])
# (39, ['efficiency,tracking,business', 'units,effective', 'communication'])
# (40, ['architecture,dashboards,deliverables,legal,presentations,financial', 'reporting,senior', 'management,team', 'lead'])
# (41, ['commodity,initiative,pricing,risk,structuring,risk', 'management'])
# (42, ['bau,change,controlling,mitigation,risk,business', 'case,functional', 'specifications,project', 'communications,project', 'delivery,project', 'manager,requirements', 'gathering'])
# (43, ['change,conducting,deliverables,developers,engagement,governance,interpreting,retail,wholesale,business', 'requirements,process', 'improvement,senior', 'management,stakeholder', 'engagement,team', 'lead,workshop', 'facilitation,user', 'acceptance', 'testing'])
# (44, ['analyses,enquiries,feedback,interventions,learning,partnerships,proactive,human', 'resources,programme', 'design,training', 'facilitation,learning', 'and', 'development'])
# (45, ['efficiency,enquiries,financials,mis,processing,reviews,business', 'units,functional', 'specifications,ms', 'access,operating', 'systems,risk', 'control,technical', 'support'])
# (46, ['analytics,budgeting,cadence,conducting,contracts,deliverables,indonesia,leadership,parties,partnerships,strategy,tracking,big', 'data,operations', 'management,project', 'management,strategic', 'alliances,strategy', 'development,strategy', 'execution,operational', 'due', 'diligence'])
# (47, ['cash,channel,feedback,processing,trends,client', 'service,customer', 'satisfaction,trade', 'services'])
# (48, ['assessment,budgeting,capital,funding,liquidity,mis,presentation,pricing,risk,sourcing,business', 'analytics,decision', 'making,institutional', 'banking,portfolio', 'management,quantitative', 'analysis'])
# (49, ['coordination,upgrades,production', 'support,month', 'end', 'close,user', 'acceptance', 'testing'])
# (50, ['architectural,articulation,change,channel,collaboration,demand,governance,reliable,roadmap,self,stability,strategy,banking', 'technologies,innovative', 'thinking,production', 'support,solution', 'delivery'])
# (51, ['accountability,change,channel,collaboration,crm,debt,flexible,governance,mobility,orientation,risk,roadmap,self,banking', 'technologies'])
# (52, ['feedback,trends,validation,wireframes,business', 'requirements,interaction', 'design,user', 'experience,user', 'journeys'])
# (53, ['automation,coaching,consumer,driving,engagement,forecasting,processing,productivity,risk,stp,strength,yield,banking', 'operations,consumer', 'banking,cost', 'management,customer', 'journeys,demand', 'management,operational', 'risk,process', 'development,process', 'efficiency,resource', 'planning'])
# (54, ['community,concepts,consumer,creative,crm,database,email,innovation,metrics,mobile,partnerships,segmentation,selling,sms,tracking,campaign', 'management,content', 'creation,cross', 'selling,customer', 'loyalty,data', 'analytics,direct', 'mail,loyalty', 'programs'])
# (55, ['discipline,ethnography,frameworks,consumer', 'behaviour,consumer', 'insights,design', 'thinking'])
# (56, ['architecture,components,developers,finacle,maintainability,resilience,usability,vendor,continuous', 'improvement,core', 'banking,internal', 'controls,regulatory', 'requirements,service', 'orientation,software', 'development,technical', 'design'])
# (57, ['conducting,led,organizing,risk,shooting,vip,business', 'units,industry', 'research,knowledge', 'sharing,project', 'management'])
# (58, ['culture,driving,engagement,governance,risk,management', 'control,risk', 'control,risk', 'management,risk', 'mitigation,technology', 'risk'])
# (59, ['benefits,methodology,pipeline,pmo,productivity,regulatory,risk,workshops,business', 'analysis,business', 'requirements,customer', 'support,legal', 'compliance,process', 'analysis,process', 'improvement,process', 'improvements,requirements', 'gathering,test', 'cases,test', 'scenarios,workshop', 'facilitation,lean', 'six', 'sigma,root', 'cause', 'analysis,value', 'stream', 'mapping'])
# (60, ['escalation,investigation,producing,sla,uat,writing,business', 'units,customer', 'services,payment', 'services,user', 'experience'])
# (61, ['benefits,engagement,map,mining,overseas,processing,productivity,roadmap,standardization,tracking,budget', 'development,business', 'management,financial', 'goals,people', 'development,performance', 'metrics,strategic', 'business,strategic', 'planning,long', 'range', 'planning,training', 'and', 'assessment,training', 'and', 'development'])
# (62, ['assurance,awareness,coaching,controls,deviations,feedback,guides,intranet,levels,liaison,map,pricing,proactive,standardization,workflow,workshops,business', 'process,business', 'requirements,client', 'servicing,cross', 'border,legal', 'compliance,product', 'knowledge,regulatory', 'requirements'])
# (63, ['change,eod,infrastructure,itsm,jira,margin,policy,reconciliation,trading,vendor,wealth,change', 'management,change', 'requests'])
# (64, ['atm,balance,bcp,billing,change,email,feedback,investigation,processing,replenishment,stock,stocks,tracking,verification'])
# (65, ['briefing,cash,cdm,cisco,collections,credit,css,currency,custody,deliveries,disputes,financing,indemnity,kyc,media,news,prevention,processing,procurement,reviews,sanction,screening,security,sla,stationery,statistics,terrorism,tracking,transmission,uat,vendor,cash', 'operations,contact', 'centre,management', 'reporting,mis', 'reporting,money', 'laundering'])
# (66, ['circulation,credit,escalation,house,insurance,legal,securities,security,administrative', 'functions,credit', 'risk,legal', 'documentation,legal', 'documents'])
# (67, ['avaloq,bonds,cash,derivatives,efficiency,equity,escalation,event,processing,reconciliation,regulations,reviews,securities,settlement,settlements,sfa,supervision,uat,otc', 'derivatives,structured', 'products,swift', 'alliance,team', 'leader'])
# (68, ['avaloq,cash,escalation,processing,reconciliation,regulations,securities,settlement,sfa,tracking,swift', 'alliance,team', 'leader'])
# (69, ['advisory,assessment,credit,geography,groups,initiative,isda,levels,negotiations,origination,pitching,rfp,security,sound,supervision,treasury,valuation,capital', 'markets,capital', 'structure,cash', 'flow,client', 'coverage,corporate', 'finance,cross', 'selling,deal', 'execution,institutional', 'banking,proactive', 'monitoring,transaction', 'services'])
# (70, ['automation,consumer,dashboard,deliverables,escalation,house,readiness,regulatory,scorecard,banking', 'operations,consumer', 'banking,risk', 'control'])
# (71, ['access,administration,broadcast,cash,intranet,negotiation,rates,statistics,templates,treasury,foreign', 'currency,mis', 'reporting,special', 'projects'])
# (72, ['access,audit,availability,backup,change,citrix,deployment,engineers,impact,less,mentoring,middleware,proactive,procurement,reliable,resilience,upgrades,validation,windows,asset', 'management,capacity', 'planning,change', 'requests,infrastructure', 'services,operational', 'excellence,patch', 'management,performance', 'analysis,performance', 'management,problem', 'management,requirement', 'gathering,service', 'delivery,service', 'recovery,technical', 'assistance,root', 'cause', 'analysis'])
# (73, ['access,audit,availability,backup,change,engineers,images,impact,ims,less,mentoring,proactive,procurement,provisioning,reliable,resilience,upgrades,validation,vmware,asset', 'management,capacity', 'planning,change', 'requests,infrastructure', 'services,operational', 'excellence,patch', 'management,performance', 'analysis,problem', 'management,requirement', 'gathering,service', 'delivery,service', 'recovery,technical', 'assistance,root', 'cause', 'analysis'])
# (74, ['deliverables,designs,feedback,innovative,interaction,wireframes,best', 'practices,product', 'management,user', 'research,visual', 'design'])
# (75, ['architecture,availability,collaboration,confidentiality,determination,engineers,firewalls,ids,infrastructure,innovative,integrity,levels,mitigation,routers,security,sensors,switches,load', 'balancers,network', 'infrastructure,security', 'operations'])
# (76, ['audit,bcp,consultation,controls,legal,mitigation,orm,security,vendor,data', 'analysis,external', 'audit,internal', 'controls,it', 'risk,process', 'improvement,process', 'improvements,project', 'managers,quality', 'assurance,service', 'providers'])
# (77, ['accruals,audit,bloomberg,calculations,change,collateral,csa,derive,dispute,efficiency,escalation,gmra,margin,mitigation,otc,payments,performing,pricing,ratings,reconciliations,securities,settlement,stp,valuation,business', 'analysis,collateral', 'management,credit', 'risk,issue', 'resolution,middle', 'office,process', 'improvements,regulatory', 'requirements,risk', 'management'])
# (78, ['advertising,banners,branding,brochures,collaboration,communications,distribution,graphics,intranet,stories,templates,tracking'])
# (79, ['audit,billing,bloomberg,conflict,logistics,murex,presentation,settlement,budget', 'tracking,expense', 'management'])
# (80, ['aml,banking,bankruptcy,cft,credit,evidence,fit,joiners,litigation,mis,policy,regulations,screening,signs,terrorism,business', 'units,human', 'resource,regulatory', 'requirements,team', 'lead,anti', 'money', 'laundering'])
# (81, ['audit,auditing,audits,completion,controls,procurement,human', 'resources,regulatory', 'compliance,anti', 'money', 'laundering,operational', 'risk', 'management'])
# (82, ['awareness,briefing,coaching,controls,efficiency,health,inspection,templates,continuous', 'improvement,management', 'review,operational', 'risk,risk', 'control'])
# (83, ['accounting,audit,auditing,audits,controls,credit,international,regulatory,reviews,treasury,audit', 'committee,corporate', 'banking,cross', 'border,private', 'banking,structured', 'trade,trade', 'finance'])
# (84, ['concepts,coverage,downstream,groups,legal,logistics,uat,workshops,best', 'practices,impact', 'analysis,solution', 'design,test', 'cases,uat', 'testing,business', 'impact', 'analysis,subject', 'matter', 'experts'])
# (85, ['audit,auditing,audits,controls,overseas,risk,audit', 'committee'])
# (86, ['automation,transformation,user', 'requirements'])
# (87, ['agile,bau,benefits,coaching,communications,forecasting,levels,metrics,organisation,roadmap,transformation,vision,program', 'management,stakeholder', 'engagement'])
# (88, ['balances,campaign,campaigns,cards,credit,dashboards,driving,engagement,initiation,legal,metrics,revenue,targets,tracking,trends,variances,business', 'analytics,credit', 'risk,performance', 'analysis,unsecured', 'loans'])
# (89, ['analytics,balance,cards,credit,driving,feedback,risk,strategy,trend,business', 'plan,customer', 'experience,financial', 'goals,market', 'intelligence,product', 'innovation,value', 'propositions'])
# (90, ['acting,advisory,capital,collateral,deals,distribution,funding,international,investment,legal,liquidity,mitigation,optimisation,origination,regulations,regulatory,securitization,strategy,tax,trading,trends,yield,asset', 'allocation,balance', 'sheet,cash', 'flow,identifying', 'trends,market', 'research,pricing', 'analysis,relative', 'value'])
# (91, ['interpretation,licensing,regulations,regulatory,rules,sound,business', 'initiatives,business', 'transactions,compliance', 'testing,trade', 'surveillance'])
# (92, ['audit,awareness,bcp,escalation,legal,liaison,outsourcing,reviews,risk,validation,operational', 'risk,regulatory', 'requirements,risk', 'compliance,risk', 'management,senior', 'management,services', 'delivery'])
# (93, ['capital,communications,composition,conducting,funding,funds,investors,responsibility,strategy,supervision,wholesale,balance', 'sheet,senior', 'management'])
# (94, ['accounting,analysts,analytics,articulation,benchmarking,flash,forecast,forecasting,governance,investments,optimizations,performing,quantitative,trends,cost', 'management,financial', 'control,process', 'improvements,strategic', 'initiatives'])
# (95, ['cards,processing,scheme,terminal,system', 'requirements,system', 'testing,unsecured', 'loans'])
# (96, ['administration,history,mis,payments,profitability,risk,schedules'])
# (97, ['benefits,coaching,event,presentations,productivity,risk,tracking,continuous', 'improvement,data', 'mining,services', 'delivery,visual', 'management'])
# (98, ['delegation,expenses,gst,pay,payments,processing,supervisory,tax,uat,vendor,withholding,balance', 'sheet,bank', 'reconciliation,withholding', 'tax'])
# (99, ['bau,coordination,cro,exercises,kpi,leadership,parties,reviews,issue', 'resolution'])
# (100, ['guides,international,regulatory,balance', 'sheet,commercial', 'banking,corporate', 'treasury,cross', 'border'])
# (101, ['credit,institutional,originations,switch,credit', 'reports'])
# (102, ['campaign,campaigns,craft,event,targets,business', 'analytics,internal', 'controls,young', 'adults'])
# (103, ['craft,editorial,http,websites,social', 'media'])
# (104, ['administrative,asset,collateral,consolidation,filing,logging,administrative', 'functions,data', 'sheets,user', 'acceptance', 'testing'])
# (105, ['consultants,credit,excel,independent,initiative,legal,pitching,presentation,selection,corporate', 'credit,due', 'diligence,legal', 'documentation,pitch', 'books,term', 'sheets,visual', 'basic'])
# (106, ['consultants,credit,excel,independent,initiative,legal,pitching,presentation,selection,corporate', 'credit,due', 'diligence,legal', 'documentation,pitch', 'books,term', 'sheets,visual', 'basic'])
# (107, ['consultants,credit,excel,independent,initiative,legal,pitching,presentation,selection,corporate', 'credit,due', 'diligence,legal', 'documentation,pitch', 'books,term', 'sheets,visual', 'basic'])
# (108, ['asset,avaloq,bms,credit,lean,observation,offices,performing,risk,settlement,sop,uat'])
# (109, ['assessment,asset,brokers,credit,csa,funds,gmra,isda,negotiation,performing,ratings,regulatory,risk,securities,sound,counterparty', 'risk,credit', 'monitoring,financial', 'institutions,risk', 'assessment'])
# (110, ['analytics,credit,dashboard,risk,basel', 'ii,credit', 'risk,economic', 'capital,portfolio', 'risk'])
# (111, ['banking,budgets,policy,reviews,transformation,business', 'management,train', 'staff'])
# (112, ['bpm,coverage,impact,responsibility,uat,business', 'requirements,test', 'cases'])
# (113, ['adjustments,cash,commentaries,commentary,deals,estimates,ledger,movement,rates,reconciliation,reserves,risk,var,balance', 'sheet,front', 'office,general', 'ledger,management', 'reporting,operational', 'efficiency,uat', 'testing'])
# (114, ['adjustments,banking,cash,commentaries,commentary,deals,estimates,ledger,movement,rates,reconciliation,reserves,risk,var,balance', 'sheet,front', 'office,general', 'ledger,management', 'reporting,operational', 'efficiency,risk', 'management,uat', 'testing'])
# (115, ['accounting,automation,bms,controls,funding,hcm,mis,murex,overseas,oversight,parties,responsibility,wholesale,accounting', 'policy,treasury', 'systems'])
# (116, ['as400,brokers,cash,coverage,financing,funds,margin,processing,reconciliation,regulations,settlement,sgx,sla,sop,trust,uat,vendor,cash', 'management,journal', 'entries,money', 'market,monthly', 'reporting,test', 'cases'])
# (117, ['as400,cash,coverage,financing,funds,map,margin,processing,reconciliation,regulations,risk,settlement,sgx,sla,sop,trust,vendor,verification,cash', 'management,journal', 'entries,money', 'market,monthly', 'reporting,team', 'player,test', 'cases,user', 'acceptance', 'testing'])
# (118, ['campaigns,integrity,rewards,administrative', 'support,data', 'management,general', 'administration,service', 'excellence'])
# (119, ['agility,axes,banking,benefits,capital,competitive,credit,deals,deposits,differentiation,dynamic,groups,leadership,loans,origination,pipelines,rms,treasury,best', 'practices,capital', 'structure,cash', 'management,commercial', 'banking,corporate', 'restructuring,financial', 'services,fixed', 'income,foreign', 'exchange,fund', 'raising,global', 'finance,investment', 'banking,management', 'skills,organization', 'skills,product', 'development,relationship', 'management,risk', 'management,south', 'asia,southeast', 'asia,stakeholder', 'management,team', 'player,time', 'management,trade', 'finance,equity', 'capital', 'markets'])
# (120, ['advisory,aviation,axes,capital,cash,chemical,commerce,commodities,commodity,credit,driving,energy,equity,infrastructure,manufacturing,media,metals,origination,originations,oversight,risk,shipping,structuring,telecommunications,treasury,capital', 'markets,credit', 'risk,cross', 'selling,financial', 'institutions,financial', 'services,global', 'finance,institutional', 'clients,investment', 'banking,middle', 'office,public', 'sector,real', 'estate,senior', 'management,south', 'asia,southeast', 'asia,trade', 'credit,transaction', 'banking,debt', 'capital', 'markets,equity', 'capital', 'markets'])
# (121, ['access,bpm,concepts,confidentiality,dashboards,diagrams,expert,fit,house,leadership,modeling,regulations,rollout,business', 'process,business', 'units,change', 'management,process', 'modeling'])
# (122, ['bridge,sit,strategy,uat,workshops,business', 'requirements,customer', 'journeys,functional', 'requirements'])
# (123, ['commercial,consultation,engagement,legal,negotiations,producing,regulatory,selection,sla,business', 'requirements,client', 'service,client', 'servicing,market', 'knowledge,product', 'specialists,project', 'management,project', 'plans,system', 'development,transaction', 'processing,service', 'level', 'agreements,user', 'acceptance', 'testing'])
# (124, ['analytical,derivatives,independent,isda,law,profit,risk,sql,communication', 'skill,excel', 'vba,financial', 'engineering,legal', 'documentation'])
# (125, ['campaign,enquiries,payments,remittances,customer', 'experience,regulatory', 'reporting'])
# (126, ['balances,campaign,enquiries,revenue,customer', 'experience,regulatory', 'reporting'])
# (127, ['banking,enquiries,feedback,trends,customer', 'interaction,customer', 'satisfaction'])
# (128, ['banking,enquiries,feedback,trends,customer', 'interaction,customer', 'satisfaction'])
# (129, ['channel,competitive,credit,learning,regulatory,reviews,sound,stress,trends,turnaround,underwriting,account', 'planning,approval', 'process,portfolio', 'risk,sme', 'banking'])
# (130, ['agile,audit,availability,budgets,demand,digital,directing,efficiency,flex,frameworks,governance,image,leadership,levels,proactive,productivity,regulatory,roadmap,schedules,utilities,business', 'units,delivery', 'management,project', 'managers,regulatory', 'requirements,software', 'development'])
# (131, ['advanced,analytical,analytics,evaluation,infrastructure,modelling,optimisation,security,tracking,trend,continuous', 'improvement,data', 'management,financial', 'crime,quantitative', 'models,variance', 'analysis'])
# (132, ['advisory,cash,credit,groups,revenue,reviews,rfp,supervision,treasury,capital', 'markets,client', 'coverage,cross', 'selling,deal', 'execution,fixed', 'income,real', 'estate,structured', 'finance,operational', 'risk', 'management'])
# (133, ['courses,coverage,culture,interpretation,licensing,regulations,regulatory,rules,sound,teamwork,business', 'initiatives,business', 'transactions,compliance', 'training,consumer', 'banking,cross', 'border,internal', 'compliance,marketing', 'materials,regulatory', 'requirements'])
# (134, ['agile,collaborative,deployment,best', 'practices,leadership', 'skill,software', 'solutions'])
# (135, ['charter,driving,reviews,voice,information', 'gathering'])
# (136, ['charter,controls,discipline,driving,engineers,governance,infrastructure,strategy,design', 'documents,information', 'gathering,solution', 'design'])
# (137, ['bau,mis,business', 'analytics,process', 'review'])
# (138, ['abstraction,actuate,agile,analytical,analytics,coding,concepts,database,datamart,designing,discipline,enforcement,java,levels,maintainability,murex,obiee,oracle,programming,scrum,sdlc,sql,treasury,troubleshooting,unix,webi,business', 'applications,business', 'intelligence,crystal', 'reports,data', 'marts,data', 'structures,data', 'warehouse,design', 'patterns,design', 'specifications,etl', 'tools,metadata', 'management,reporting', 'tool,server', 'architecture,shell', 'scripting,sql', 'pl,sun', 'solaris,technical', 'design,web', 'development,possess', 'strong', 'analytical'])
# (139, ['bau,calm,driving,simulation,sit,uat,business', 'units,requirement', 'gathering'])
# (140, ['contract,procurement,sponsorship,tactics,invoice', 'processing,marketing', 'communication,user', 'experience'])
# (141, ['consistency,consumer,dashboard,deliverables,house,organisation,readiness,regulatory,risk,scorecard,strategy,transformation,banking', 'operations,consumer', 'banking,risk', 'control,risk', 'management'])
# (142, ['regression,business', 'requirements,integration', 'testing,release', 'notes,test', 'scripts'])
# (143, ['digitization,methodology,consumer', 'banking,project', 'management,project', 'management', 'plan'])
# (144, ['digitization,methodology,consumer', 'banking,project', 'management,project', 'management', 'plan'])
# (145, ['digitization,methodology,consumer', 'banking,project', 'management,project', 'management', 'plan'])
# (146, ['digitization,methodology,pms,strategy,consumer', 'banking,project', 'management,vendor', 'relationships,project', 'management', 'plan'])
# (147, ['administration,analytics,bau,coordination,database,derive,downstream,infrastructure,specifications,transformation,uat,verification,change', 'requests,functional', 'specifications,impact', 'analysis,requirement', 'specifications,system', 'testing,test', 'scenarios,user', 'acceptance', 'testing'])
# (148, ['agile,change,house,iwork,methodology,web,application', 'support,infrastructure', 'security,market', 'risk,product', 'control,risk', 'control,solution', 'delivery,technology', 'solutions'])
# (149, ['campaigns,digital,enquiries,feedback,insurance,parties,regulations,risk,sound,legal', 'marketing,sales', 'training'])
# (150, ['collectors,credit,productivity,risk,schedules,team', 'performance'])
# (151, ['availability,bau,groups,health,trading,uat,business', 'requirements,business', 'units,trading', 'platforms'])
# (152, ['bau,brd,learning,readiness,uat,wealth,best', 'practices,business', 'requirements,business', 'units,equity', 'trading,project', 'implementation,trading', 'platforms'])
# (153, ['accounting,coverage,economics,equities,interaction,investment,news,publishing,traders,valuation,equity', 'sales,investor', 'relations'])
# (154, ['controls,engagement,frameworks,governance,reviews,risk,standardization,operational', 'excellence,risk', 'control,risk', 'management,risk', 'monitoring'])
# (155, ['developers,performing,troubleshooting,web,business', 'requirements,operational', 'support,real', 'time,requirements', 'gathering,system', 'implementation,system', 'requirements'])
# (156, ['banking,proactive,supervision,cash', 'management,cross', 'selling,customer', 'relationship', 'management,new', 'business', 'opportunities'])
# (157, ['cash,commodities,commodity,credit,energy,equity,financing,groups,negotiations,quantitative,risk,security,treasury,capital', 'markets,cross', 'selling,middle', 'office,structured', 'trade,transaction', 'banking,debt', 'capital', 'markets,equity', 'capital', 'markets'])
# (158, ['accounting,asset,credit,debt,distribution,legal,liquidity,regulations,regulatory,reviews,securitization,structural,structures,structuring,tax,regulatory', 'capital,secured', 'financing,structured', 'finance,tax', 'accounting'])
# (159, ['advertising,affinity,campaigns,communications,dynamic,media,merchandising,social,brand', 'identity,brand', 'strategy,consumer', 'banking,digital', 'media,marketing', 'materials'])
# (160, ['advertising,affinity,campaigns,communications,media,social,brand', 'identity,brand', 'strategy,consumer', 'banking,digital', 'media,marketing', 'materials'])
# (161, ['infrastructure,mis,presentation,risk,sourcing,business', 'analytics,institutional', 'investors,quantitative', 'analysis'])
# (162, ['diagrams,vendor,business', 'requirements,process', 'flow'])
# (163, ['drafting,legal,litigation,regulatory,business', 'initiatives,legal', 'support,private', 'banking,product', 'offerings,service', 'providers'])
# (164, ['audit,bcm,bcp,budgeting,completion,dashboards,expenses,forecast,metrics,mis,reviews,risk,tracking,business', 'units,client', 'service,external', 'audit,internal', 'control,operational', 'risk,regulatory', 'audits,self', 'assessment'])
# (165, ['awareness,bcp,courses,frameworks,governance,readiness,regulatory,risk,best', 'practices,business', 'continuity,compliance', 'training,event', 'management,management', 'reporting,operational', 'risk,risk', 'control,risk', 'management,senior', 'management,operational', 'risk', 'management'])
# (166, ['agility,architectural,architectures,designs,infrastructure,maintainability,resilience,application', 'architecture,conceptual', 'designs,design', 'specifications,functional', 'requirements,service', 'orientation,technical', 'design'])
# (167, ['analytical,awareness,basic,change,digital,distribution,engagement,health,medical,mis,organized,protection,retirement,rollout,strategy,systematic,trends,best', 'practices,customer', 'experience,digital', 'channels,digital', 'marketing,financial', 'planning,legacy', 'planning,marketing', 'strategy,risk', 'management,sales', 'performance,special', 'projects,user', 'experience,wealth', 'accumulation,web', 'analytics'])
# (168, ['methodology,risk,consumer', 'banking,project', 'management,project', 'management', 'plan'])
# (169, ['methodology,productivity,risk,consumer', 'banking,project', 'management,project', 'management', 'plan'])
# (170, ['bau,credit,database,retail,strategy,uat,wholesale,writing,approval', 'process,project', 'implementation'])
# (171, ['campaigns,community,components,digital,fact,integration,multimedia,trends,web,best', 'practices,consumer', 'behavior,content', 'marketing,development', 'design,digital', 'marketing,emerging', 'technologies,market', 'intelligence,social', 'analytics,social', 'media,strategic', 'insights,social', 'media', 'analytics,user', 'acceptance', 'testing'])
# (172, ['cap,coverage,credit,energy,infrastructure,power,utilities,client', 'coverage,institutional', 'banking,natural', 'resources,operational', 'risk', 'management'])
# (173, ['agile,audit,coaching,controls,devops,feedback,led,methodology,organizing,regulatory,reviews,scrum,sdlc,tailoring,tdd,validation,verification,continuous', 'improvement,continuous', 'integration,following', 'up,project', 'initiation,project', 'manager,quality', 'assurance,release', 'management,risk', 'assessment,trusted', 'advisor'])
# (174, ['abstract,access,automation,interviews,specifications,business', 'process,data', 'analytics,software', 'development,workflow', 'analysis'])
# (175, ['finacle,fix,sit,uat,test', 'planning'])
# (176, ['architectural,integration,options,surface,tracking,uat,cash', 'management,functional', 'requirements,institutional', 'banking,payment', 'systems,process', 'improvement,relationship', 'management,subject', 'matter', 'experts'])
# (177, ['architectural,integration,options,surface,tracking,uat,cash', 'management,functional', 'requirements,institutional', 'banking,payment', 'systems,process', 'improvement,relationship', 'management,subject', 'matter', 'experts'])
# (178, ['cards,deployment,driving,ibm,infrastructure,leadership,sme,stage,tracking,business', 'case'])
# (179, ['escalation,specifications,tracking,business', 'case,business', 'requirements,feasibility', 'studies,project', 'implementation,project', 'risk,solution', 'design,system', 'integration'])
# (180, ['benefits,impact,reconciliation,skill,specifications,transparency,business', 'case,business', 'requirements,feasibility', 'studies,project', 'management,solution', 'design,test', 'scripts'])
# (181, ['change,coordination,interventions,presentation,hr', 'policies,human', 'resources,people', 'management,policy', 'development,private', 'bank,regional', 'management'])
# (182, ['change,coordination,interventions,risk,consumer', 'banking,hr', 'policies,human', 'resources,people', 'management,policy', 'development'])
# (183, ['change,coordination,interventions,risk,hr', 'policies,human', 'resources,institutional', 'banking,people', 'management,policy', 'development'])
# (184, ['analyses,chinese,credit,dcf,gts,independence,negotiation,organized,security,sound,supervision,treasury,valuation,capital', 'markets,capital', 'structure,cash', 'flow,corporate', 'finance,proactive', 'monitoring,senior', 'management'])
# (185, ['change,conducting,deliverables,developers,engagement,governance,interpreting,retail,business', 'analyst,business', 'requirements,senior', 'management,stakeholder', 'engagement,workshop', 'facilitation,user', 'acceptance', 'testing'])
# (186, ['coverage,sit,uat,test', 'cases'])
# (187, ['statistics,trust,management', 'reporting,standard', 'operating', 'procedures'])
# (188, ['designs,ownership,reviews,sdlc,strategy,transparency,data', 'analysis,data', 'architecture,data', 'governance,data', 'management,data', 'profiling,data', 'quality'])
# (189, ['aml,fraud,integrity,metrics,sanctions,surveillance,trends,continuous', 'improvement,financial', 'crime'])
# (190, ['completion,credit,deliverables,efficiency,escalation,proactive,productivity,regulatory,savings,business', 'requirements,process', 'improvement'])
# (191, ['articles,benchmarking,commercialization,efficiency,engagement,indonesia,mis,replication,revenue,risk,structuring,targets,tracking,best', 'practices,product', 'offerings,risk', 'monitoring,thought', 'leadership'])
# (192, ['levels,peoplesoft,reconciliation,turnaround,administrative', 'support,asset', 'management,fixed', 'assets,management', 'system,system', 'testing'])
# (193, ['access,coaching,counselling,culture,evaluation,mentoring,skill,teambuilding,personal', 'development,soft', 'skills,training', 'and', 'development,training', 'needs', 'analysis'])
# (194, ['architectural,communications,hyperion,interfacing,mis,producing,group', 'consolidation,management', 'reporting'])
# (195, ['as400,bonds,coverage,financing,processing,settlement,sgx,shares,sop,uat,lotus', 'notes'])
# (196, ['assessment,collections,consumer,credit,downstream,drafting,enquiries,impact,investigations,liaison,parties,business', 'requirements,credit', 'bureau,system', 'testing,test', 'scripts'])
# (197, ['audit,audits,completion,credit,event,fraud,independent,presentation,rcsa,regulatory,risk,front', 'office,operational', 'risk,control', 'self', 'assessment'])
# (198, ['aml,audit,cft,change,kyc,risk,sanction,uat,management', 'reporting,control', 'self', 'assessment,user', 'acceptance', 'testing'])
# (199, ['assessment,awareness,committees,controls,impact,mitigation,orm,risk,tailoring,trends,best', 'practices,board', 'level,emerging', 'trends,operational', 'risk,risk', 'analysis,risk', 'governance,risk', 'management,risk', 'mitigation,senior', 'management,trend', 'analysis,control', 'self', 'assessment,operational', 'risk', 'management'])
# (200, ['articles,branding,communications,innovative,intranet,media,photos,strategy,digital', 'channels,employee', 'communications,social', 'media'])
# (201, ['awareness,coaching,expert,feedback,regulatory,supervisory,wealth,business', 'ethics,credit', 'review,cross', 'selling,customer', 'satisfaction,general', 'insurance,service', 'quality'])
# (202, ['interfaces,murex,mxml,sql,unix,core', 'java,data', 'interfaces,design', 'development,market', 'data,project', 'managers,technical', 'support,user', 'requirements'])
# (203, ['administration,confirmation,email,equity,rms,verification,equity', 'trading,investment', 'advisory,research', 'analysis'])
# (204, ['benefits,methodology,productivity,risk,tracking,consumer', 'banking,design', 'documents,functional', 'design,project', 'management,system', 'migration,user', 'requirements,project', 'management', 'plan'])
# (205, ['assessment,budgets,community,construction,deployment,innovation,oversight,responsibility,selection,transformation,vendor,product', 'design,product', 'testing,value', 'propositions,vendor', 'management'])
# (206, ['banking,impact,innovation,transformation,data', 'science,research', 'and', 'development'])
# (207, ['bridge,sound,uat,workshops,business', 'requirements,subject', 'matter', 'experts'])
# (208, ['deals,risk,workflow,front', 'office,middle', 'office,office', 'operations,product', 'control,structured', 'products,term', 'sheets'])
# (209, ['cdd,futures,policy,tracking,treasury'])
# (210, ['cdd,futures,policy,tracking,treasury,uat,static', 'data,system', 'specification'])
# (211, ['accounting,analytics,articulation,benchmarking,budgeting,campaign,campaigns,cards,flash,forecast,integrity,investments,optimization,performing,tracking,trends,business', 'initiatives,business', 'planning,financial', 'control,performance', 'analysis,process', 'improvements,strategic', 'initiatives'])
# (212, ['architecture,deliverables,derive,estimates,governance,house,initiative,metrics,reliable,tracking,project', 'plans,requirements', 'analysis'])
# (213, ['acting,availability,deviations,efficiency,escalation,fashion,integrity,measurements,policy,targets,daily', 'operations,problem', 'management'])
# (214, ['associate,banking,campus,edge,innovation,innovative,learning,mentorship,networking,personal', 'development,project', 'management,senior', 'management,banking', 'and', 'finance'])
# (215, ['edm,email,engagement,promotions,sem,seo,websites,channel', 'strategy,mobile', 'apps,social', 'media'])
# (216, ['edm,email,engagement,promotions,sem,seo,websites,channel', 'strategy,mobile', 'apps,social', 'media'])
# (217, ['banking,cards,driving,health,performing,revenue,strategy,targets,customer', 'experience,service', 'delivery,new', 'business', 'opportunities'])
# (218, ['administration,budgets,disbursement,logistics,workshops'])
# (219, ['analyses,basic,dashboards,databases,patterns,trends,verification,data', 'mapping,user', 'requirements'])
# (220, ['analytical,awareness,diving,excel,processing,risk,self,strategy,microsoft', 'office,operational', 'risk,organizational', 'skills,presentation', 'skills,team', 'player,microsoft', 'power', 'point,problem', 'solving', 'skills'])
# (221, ['aml,change,digital,governance,innovation,innovative,kyc,leadership,led,onboarding,orientation,partnerships,platforms,plays,transformation,business', 'units,customer', 'experience,solution', 'delivery'])
# (222, ['administrative,banking,expert,innovative,investment,treasury,wealth,financial', 'analysis,product', 'specialists'])
# (223, ['administrative,banking,expert,innovative,investment,treasury,wealth,financial', 'analysis,product', 'specialists'])
# (224, ['banking,financials,printing,settlement,credit', 'review,customer', 'service,sales', 'performance,team', 'leader'])
# (225, ['financials,pricing,printing,restructuring,settlement,credit', 'review,customer', 'service,sales', 'performance,team', 'leader'])
# (226, ['bau,sourcing,treasury,valuation,front', 'office,market', 'data,uat', 'testing'])
# (227, ['banking,cash,deposits,enquiries,customer', 'satisfaction,regulatory', 'requirements,service', 'delivery'])
# (228, ['empowerment,evaluation,law,legal,liquidation,loans,mis,pay,performing,policy,power,price,restructuring,risk,administrative', 'support,consumer', 'banking,credit', 'risk,due', 'diligence,mis', 'reporting'])
# (229, ['asset,equity,sourcing,treasury,valuation,front', 'office,market', 'data,uat', 'testing'])
# (230, ['kyc,proactive,strategy,suitability,client', 'acquisition,regulatory', 'requirements,team', 'lead'])
# (231, ['campaigns,differentiation,engagement,governance,groups,infrastructure,innovation,mis,pricing,regulations,regulatory,revenue,rfp,trends,approval', 'process,due', 'diligence,market', 'sizing,partner', 'management,product', 'knowledge,relationship', 'management,value', 'propositions'])
# (232, ['campaigns,differentiation,engagement,governance,groups,infrastructure,innovation,mis,pricing,regulations,regulatory,revenue,rfp,roadmap,rollout,sequencing,timing,trends,approval', 'process,due', 'diligence,market', 'sizing,partner', 'management,product', 'knowledge,relationship', 'management,value', 'propositions,subject', 'matter', 'experts'])
# (233, ['derive,business', 'information,customer', 'experience,service', 'processes,strategic', 'initiatives,thought', 'leadership'])
# (234, ['campaigns,legal,levels,regulatory,financial', 'markets,legal', 'compliance,security', 'audit'])
# (235, ['campaign,campaigns,css,enquiries,legal,levels,metrics,offshore,policy,regulations,regulatory,sla,tracking,cross', 'border,financial', 'markets,legal', 'compliance,management', 'reporting,security', 'audit,value', 'proposition,wealth', 'management,customer', 'value', 'proposition'])
# (236, ['campaigns,legal,levels,offshore,regulations,regulatory,cross', 'border,financial', 'markets,legal', 'compliance,security', 'audit,value', 'proposition,wealth', 'management,customer', 'value', 'proposition'])
# (237, ['calibration,independent,regulations,targets,telesales,campaign', 'planning,customer', 'satisfaction,following', 'up,general', 'insurance,quality', 'assurance,sales', 'process,written', 'communication'])
# (238, ['assessment,audit,change,independent,kpi,liaison,metrics,processing,reviews,risk,rms,treasury,business', 'operations,due', 'diligence,process', 'implementation,risk', 'management,trend', 'analysis,new', 'product', 'launch,operational', 'risk', 'management'])
# (239, ['administrative,campaigns,communications,crowdsourcing,innovation,community', 'management,event', 'management'])
# (240, ['advisory,equity,origination,regulatory,reit,securities,trust,valuation,deal', 'structuring,due', 'diligence,financial', 'modeling,investment', 'banking'])
# (241, ['asset,communications,components,consistency,consumer,editing,editorial,fit,house,investment,publications,reach,rewriting,securities,strategy,writing,due', 'diligence,investment', 'advisory,investment', 'research,investment', 'strategies,media', 'production,new', 'media,online', 'communications,wealth', 'management'])
# (242, ['asset,communications,components,consistency,consumer,editing,editorial,fit,house,investment,publications,reach,rewriting,securities,strategy,writing,due', 'diligence,investment', 'advisory,investment', 'research,investment', 'strategies,media', 'production,new', 'media,online', 'communications,wealth', 'management'])
# (243, ['architecture,audit,availability,confidentiality,controls,engineers,infrastructure,innovative,integrity,levels,mitigation,regulatory,security,vendor,it', 'risk,risk', 'control,security', 'operations,service', 'providers'])
# (244, ['awareness,banking,campaigns,channel,commercialization,competitive,digital,driving,excel,financing,innovative,international,map,mobile,pricing,regulations,responsibility,road,tracking,usability,cash', 'management,direct', 'marketing,product', 'development,product', 'management,product', 'planning,product', 'strategy,real', 'time,requirement', 'specifications,sales', 'operations,stakeholder', 'management,supply', 'chain,trade', 'finance,user', 'experience'])
# (245, ['enquiries,processing,sla,vetting,process', 'improvement,trade', 'finance,letter', 'of', 'credit'])
# (246, ['confirmation,efficiency,isda,mis,policy,productivity,validation,valuation'])
# (247, ['accountability,digital,distribution,editorial,edms,legal,linkedin,organisation,platforms,twitter,websites,content', 'development,content', 'management,content', 'production,content', 'strategy'])
# (248, ['completion,coordination,deliverables,engagement,ftp,overseas,oversight,performing,turnaround,business', 'initiatives,emerging', 'markets,impact', 'analysis,mis', 'reporting,funds', 'transfer', 'pricing,month', 'end', 'close,user', 'acceptance', 'testing'])
# (249, ['interviews,patterns,trends,visio,workshops,business', 'process,workflow', 'analysis,business', 'process', 'mapping'])
# (250, ['balance,banking,credit,evaluation,proactive,profit,profitability,referrals,revenue,rms,supervision,targets,credit', 'review,customer', 'relationship', 'management,new', 'business', 'opportunities'])
# (251, ['balance,campaign,campaigns,credit,impact,initiation,legal,profitability,sound,tracking,business', 'analytics,credit', 'cards,line', 'management,operational', 'efficiency,regulatory', 'requirements,system', 'automation,sales', 'and', 'marketing'])
# (252, ['cards,governance,infrastructure,leadership,security,stage,tracking,treasury,business', 'case,subject', 'matter', 'experts'])
# (253, ['committees,consistency,controls,metrics,outsourcing,partnering,regulatory,risk,suitability,tracking,turnaround,service', 'level', 'agreements'])
# (254, ['bancassurance,cbm,credit,distribution,financing,protection,regulatory,scheme,validation,business', 'continuity,corporate', 'insurance,financial', 'planning,value', 'propositions,business', 'continuity', 'management'])
# (255, ['availability,awareness,backup,change,dashboard,escalation,health,investigation,vendor,verification,batch', 'processing,capacity', 'management,change', 'management,incident', 'reporting'])
# (256, ['aml,bau,budgets,contract,fraud,grc,kyc,outsourcing,vendor,solution', 'architecture'])
# (257, ['interviews,patterns,trends,visio,business', 'process,workflow', 'analysis,business', 'process', 'mapping'])
# (258, ['collaboration,communications,conducting,culture,learning,change', 'management,marketing', 'communications,project', 'managers,staff', 'engagement,strategic', 'marketing'])
# (259, ['audit,budgeting,credit,deliverables,hfm,infrastructure,liquidity,mis,regulatory,reviews,risk,rollout,issue', 'resolution,project', 'delivery,project', 'management,service', 'providers'])
# (260, ['deployment,vendor,business', 'analyst,cost', 'estimation,functional', 'specifications,project', 'manager,requirements', 'gathering,strategy', 'planning'])
# (261, ['accounting,assurance,committees,controls,ownership,standardization,upstream,corporate', 'banking,general', 'ledger,office', 'operations,process', 'improvements,regulatory', 'reporting,quality', 'assurance', 'review'])
# ...
# (552, ['allocations,completion,controlling,engineers,escalation,fix,history,levels,proactive,recording,responsibility,terminal,territory,contractual', 'agreements,incident', 'management,incident', 'reporting,operations', 'management,team', 'leader'])
# (553, ['analytics,capital,coordination,credit,governance,icaap,interpretation,liquidity,regulatory,responsibility,risk,stress,consumer', 'banking,corporate', 'treasury,data', 'quality,decision', 'making,institutional', 'banking,regulatory', 'reporting,risk', 'management,risk', 'measurement,senior', 'executives,senior', 'management,stress', 'testing,operational', 'risk', 'management,research', 'and', 'analysis'])
# (554, ['adjustments,dos,rules,real', 'time'])
# (555, ['banking,cards,channel,classroom,consumer,credit,self,verification,banking', 'operations,classroom', 'training,consumer', 'banking,operating', 'models,service', 'operations,wealth', 'management'])
# (556, ['banking,cards,channel,classroom,consumer,credit,self,verification,banking', 'operations,classroom', 'training,consumer', 'banking,operating', 'models,service', 'operations,wealth', 'management'])
# (557, ['banking,cards,channel,classroom,consumer,credit,self,verification,banking', 'operations,consumer', 'banking,operating', 'models,service', 'operations,wealth', 'management'])
# (558, ['analytics,icaap,interpretation,methodology,modeling,modelling,risk,stress,supplements,credit', 'risk,data', 'quality,decision', 'making,regulatory', 'requirements,risk', 'measurement,senior', 'management,stress', 'test,stress', 'testing,credit', 'risk', 'management,research', 'and', 'analysis'])
# (559, ['infrastructure,application', 'development,business', 'requirements,production', 'support,requirements', 'gathering,software', 'development'])
# (560, ['collaboration,coordination,coverage,credit,csa,funds,isda,ownership,revenue,targets,business', 'development,cross', 'border,cross', 'selling,financial', 'institutions,private', 'equity'])
# (561, ['advisory,bcp,computer,controls,designs,diagnostics,escalation,groups,ibm,infrastructure,initiative,innovative,integration,investments,mitigation,proactive,rollout,sdlc,sla,banking', 'operations,change', 'management,continuous', 'improvement,it', 'solutions,lean', 'it,problem', 'resolution,quality', 'control,regression', 'testing,release', 'management,risk', 'management,senior', 'management,software', 'development,strategic', 'initiatives,vendor', 'management,vendor', 'relationships'])
# (562, ['assessment,banking,bau,escalation,icaap,investigation,metrics,regulatory,risk,treatment,upgrades,business', 'requirements,business', 'units,commercial', 'banking,market', 'risk,regulatory', 'requirements,risk', 'assessment,risk', 'control,senior', 'management,stress', 'testing'])
# (563, ['credit,evaluation,impact,legal,mis,policy,risk,tracking,uat,business', 'requirements,credit', 'risk,monthly', 'reporting,regulatory', 'guidelines'])
# (564, ['coaching,evaluation,levels,skill,targets,customer', 'journeys,customer', 'service,operational', 'efficiency,people', 'management,process', 'improvement,product', 'knowledge,service', 'delivery,service', 'recovery'])
# (565, ['assessment,credit,formulation,reviews,risk,sme,sound,systematic,underwriting,service', 'delivery'])
# (566, ['assessment,credit,formulation,reviews,risk,sme,sound,systematic,underwriting,service', 'delivery'])
# (567, ['administration,coordination,email,script,uat,verification,administrative', 'support,change', 'requests,daily', 'operations,functional', 'specifications,system', 'requirements,test', 'cases'])
# (568, ['audit,innovation,mis,scm,tracking,strategic', 'planning'])
# (569, ['bankruptcy,diligent,kyc,oca,processing,search,settlement,sgx,trusts,aml', 'compliance,cash', 'receipts,client', 'servicing'])
# (570, ['authorization,initiative,verification'])
# (571, ['avaloq,database,infrastructure,jira,logging,oracle,policy,reconciliation,reduce,sql,strategy,tracking,unix,upgrades,vendor,change', 'management,change', 'requests,oracle', 'database'])
# (572, ['automation,completion,deliverables,derive,drafting,specifications,uat,verification,business', 'analyst,change', 'requests,functional', 'specifications,project', 'manager,requirement', 'specifications,stress', 'testing,test', 'scenarios,user', 'requirements,user', 'acceptance', 'testing'])
# (573, ['awareness,benefits,bms,branding,coaching,consultants,crisis,deposits,engagement,enquiries,expert,feedback,investment,legal,regulations,regulatory,risk,rms,rules,business', 'process,investment', 'products,legal', 'compliance,process', 'improvement,product', 'development,product', 'launches,sales', 'and', 'marketing'])
# (574, ['collections,demand,settlement,sme'])
# (575, ['regulatory,foreign', 'exchange,money', 'market,product', 'development,risk', 'management'])
# (576, ['analytical,analytics,credit,forecasting,formulation,house,reviews,rewards,risk,scorecard,sound,advanced', 'analytics,data', 'mining'])
# (577, ['bms,commodity,derivatives,murex,risk,validation,risk', 'management'])
# (578, ['asset,derivatives,developers,house,risk,validation,warehousing,risk', 'management'])
# (579, ['analytics,innovation,listening,media,scorecard,strategy,social', 'media,social', 'media', 'strategy'])
# (580, ['csa,enquiries,mainframe,parties,processing,reduce,risk,terminations,transmission,uat,validation,visionplus,workflow,administrative', 'functions,credit', 'cards,customer', 'service,supervisory', 'experience,technical', 'support,problem', 'solving', 'skills'])
# (581, ['cash,impact,schedules,settlement,sla,service', 'quality,system', 'testing'])
# (582, ['groups,schedules,sla,service', 'quality'])
# (583, ['cmmi,education,efficiency,pmc,pmo,tracking,turnaround,vendor,culture', 'change,project', 'management,quality', 'management,service', 'providers,continuous', 'process', 'improvement'])
# (584, ['automation,bloomberg,change,communications,courses,coverage,dealers,escalation,investigation,overseas,oversight,performing,rates,recording,regulations,regulatory,reuters,reviews,risk,rules,surveillance,trading,treasury,voice,business', 'integration,business', 'units,compliance', 'training,front', 'office,middle', 'office,senior', 'management,staff', 'development,standards', 'compliance,trade', 'surveillance,training', 'material,user', 'acceptance', 'testing'])
# (585, ['bau,collateral,credit,interfaces,murex,treasury,collateral', 'management,functional', 'support,it', 'solutions,market', 'risk,requirements', 'gathering,user', 'requirements'])
# (586, ['assessment,bau,deliverables,governance,managerial,outsourcing,policy,regulatory,respect,reviews,risk,sme,financial', 'risk,management', 'review,outsourcing', 'management,process', 'improvement,regional', 'management,regulatory', 'reporting,self', 'assessment,service', 'delivery', 'management,service', 'level', 'management'])
# (587, ['efficiency,productivity,risk,sla,business', 'units,daily', 'operations,management', 'development,people', 'management,process', 'improvement,senior', 'management,structured', 'trade', 'finance'])
# (588, ['efficiency,productivity,risk,sla,business', 'units,daily', 'operations,finance', 'operations,management', 'development,people', 'management,process', 'improvement,senior', 'management,trade', 'finance'])
# (589, ['mis,policy,productivity,reduce,risk,turnaround,workflow,business', 'units,product', 'design,staff', 'engagement,unsecured', 'loans'])
# (590, ['audit,auditing,audits,completion,controls,procurement,human', 'resources,regulatory', 'compliance,anti', 'money', 'laundering,operational', 'risk', 'management'])
# (591, ['aml,audit,governance,kyc,parties,approval', 'process,problem', 'resolution,risk', 'compliance'])
# (592, ['deliverables,derive,metrics,tracking,voice,workshops,big', 'data,customer', 'experience,customer', 'journeys,customer', 'service,customer', 'surveys,service', 'quality'])
# (593, ['campaigns,coaching,copc,feedback,iso,learning,onboarding,policy,targets,contact', 'centre,cost', 'management,resource', 'planning,service', 'recovery,team', 'leadership,workforce', 'management'])
# (594, ['bau,benefits,charter,concepts,savings,stability,project', 'management,system', 'design,user', 'requirements'])
# (595, ['administration,aml,asset,cft,investment,onboarding,regulatory,reviews,risk,tax,trust,trustee,trusts,business', 'units,group', 'policy,internal', 'control,customer', 'due', 'diligence'])
# (596, ['administration,aml,asset,cft,fiduciary,investment,investments,onboarding,regulatory,reviews,risk,tax,trust,trustee,trusts,business', 'units,group', 'policy,internal', 'control,regulatory', 'requirements,customer', 'due', 'diligence'])
# (597, ['administrative,audits,bau,conducting,css,demand,escalation,expert,investigation,optimization,regulatory,screening,sdlc,uat,change', 'requests,compliance', 'testing,consumer', 'banking,demand', 'planning,financial', 'crime,institutional', 'banking,knowledge', 'base,private', 'banking,quality', 'assurance,software', 'development,user', 'training,customer', 'due', 'diligence,user', 'acceptance', 'testing'])
# (598, ['mlc,murex,vendor,back', 'office,best', 'practices,front', 'office,production', 'support,release', 'management,system', 'maintenance,user', 'acceptance', 'testing'])
# (599, ['change,escalation,impact,murex,vendor,back', 'office,best', 'practices,change', 'management,front', 'office,production', 'support,release', 'management,system', 'implementations,root', 'cause', 'analysis'])
# (600, ['access,analytical,analytics,collaborative,engagement,rules,self,customer', 'journeys,support', 'management,user', 'requirements,process', 'improvement', 'projects'])
# (601, ['drafting,legal,litigation,regulations,regulatory,business', 'initiatives,legal', 'support,private', 'banking,product', 'offerings,service', 'providers,wealth', 'management'])
# (602, ['deliverables,administrative', 'functions,business', 'units'])
# (603, ['dcm,ecm,legal,rms,structures,trust,legal', 'documents'])
# (604, ['avaloq,components,infrastructure,interfaces,itsm,policy,sql,unix,vendor,change', 'management,change', 'requests'])
# (605, ['rollout,scorecard,verification,office', 'administration,test', 'cases,trade', 'operations,uat', 'testing'])
# (606, ['house,risk,standardization,operations', 'processes,process', 'improvements,trade', 'operations,training', 'development,training', 'programs,subject', 'matter', 'experts'])
# (607, ['bau,change,community,infrastructure,investigation,promotions,reviews,tracking,business', 'units,service', 'level', 'agreements'])
# (608, ['deliverables,sit,uat,design', 'documents,test', 'cases'])
# (609, ['asset,bms,currency,investment,regulatory,risk,rms,settlement,spreadsheets,asset', 'allocation,fund', 'managers,marketing', 'materials,tactical', 'asset', 'allocation'])
# (610, ['automation,pricing,programming,structuring,traders,trading,equity', 'derivatives'])
# (611, ['assessment,capital,developers,estimates,retail,risk,segmentation,supervision,validation,liquidity', 'risk,portfolio', 'risk,stress', 'testing'])
# (612, ['metrics,marketing', 'communications,merchant', 'services,product', 'development,senior', 'management'])
# (613, ['deliverables,project', 'manager,risk', 'control,senior', 'management,team', 'spirit'])
# (614, ['deliverables,governance,mitigation,project', 'manager,risk', 'control,senior', 'management,team', 'spirit'])
# (615, ['deliverables,governance,mitigation,risk', 'control,senior', 'management,team', 'spirit'])
# (616, ['accruals,gst,invoicing,payments,sla,tax,tracking,general', 'ledger,invoice', 'processing,management', 'reporting,withholding', 'tax'])
# (617, ['employment,escalation,fraud,hip,performing,screening,surveillance,customer', 'relationship'])
# (618, ['banking,employment,escalation,fraud,hip,performing,screening,surveillance,treatment,customer', 'relationship,human', 'resources'])
# (619, ['banking,escalation,fraud,hip,performing,surveillance,customer', 'relationship,internet', 'banking'])
# (620, ['banking,change,coordination,documentations,efficiency,parties,processing,protection,regulatory,risk,security,regulatory', 'compliance,standard', 'operating', 'procedures'])
# (621, ['assessment,bau,drafting,impact,terminal,business', 'requirements,emerging', 'payments,special', 'projects,system', 'requirements,system', 'testing,test', 'scripts'])
# (622, ['accountability,adaptation,analytical,automation,budgeting,forecast,ownership,reliable,variances,business', 'initiatives,senior', 'management'])
# (623, ['banking,interfacing,roadmap,business', 'solutions,project', 'management'])
# (624, ['consultancy,funds,investment,risk,alternative', 'investments,marketing', 'communications,mutual', 'funds,product', 'training,regulatory', 'requirements,relationship', 'management'])
# (625, ['bancassurance,campaigns,forecast,health,innovative,investment,protection,revenue,savings,customer', 'service'])
# (626, ['administration,analytics,automation,coordination,derive,infrastructure,investigation,processing,reduce,risk,specifications,uat,validation,verification,change', 'requests,data', 'quality,functional', 'specifications,project', 'management,requirement', 'specifications,team', 'lead,test', 'scenarios,user', 'acceptance', 'testing'])
# (627, ['bancassurance,coaching,designing,insurance,product', 'development'])
# (628, ['advisory,architecture,english,groups,learning,policy,writers,writing,effective', 'communication'])
# (629, ['consistency,engagement,governance,international,metrics,oversight,risk,road,standardization,operational', 'risk', 'management'])
# (630, ['backup,consolidation,database,languages,methodology,obiee,sql,storage,design', 'development,product', 'control,production', 'support,project', 'governance,technical', 'documentation,technical', 'support,user', 'acceptance', 'testing'])
# (631, ['analytics,frameworks,strategy,business', 'strategy,continuous', 'improvement,customer', 'experience,customer', 'service,strategic', 'initiatives,business', 'decision', 'making'])
# (632, ['architects,budgets,deliverables,schedules,sdlc,seniors,project', 'managers,risk', 'management'])
# (633, ['coaching,deliverables,deployment,directing,dynamic,leadership,mentoring,risk,application', 'development,project', 'management,project', 'managers,project', 'plans'])
# (634, ['asset,campaigns,credit,innovation,revenue,sme,workflow'])
# (635, ['abs,competitive,positioning,reviews,strategy,tracking,trends,balanced', 'scorecard,senior', 'management'])
# (636, ['awareness,competitive,feedback,gts,health,regulatory,revenue,risk,structures,turnaround,business', 'analytics,cross', 'border,customer', 'experience,increase', 'productivity,risk', 'management,trade', 'finance,trade', 'operations,trade', 'sales,transaction', 'services'])
# (637, ['bau,budgets,contract,eps,outsourcing,payroll,recruitment,roadmap,vendor'])
# (638, ['css,designs,html,illustrator,interaction,javascript,omnigraffle,photoshop,trends,wireframes,agile', 'scrum,interaction', 'design,rapid', 'prototyping,ui', 'design,visual', 'design,wire', 'framing,human', 'computer', 'interaction'])
# (639, ['currency,funding,structural,structuring,swaps,treasury,accounting', 'policy,approval', 'process,cross', 'border,fx', 'hedging,hedge', 'accounting,transfer', 'pricing'])
# (640, ['advisory,commentary,competitive,credit,feedback,hybrids,interpretation,investment,legal,pricing,rates,trends,writing,corporate', 'actions,due', 'diligence,financial', 'goals,product', 'launches'])
# (641, ['advisory,assurance,awareness,controls,enquiries,expert,groups,oversight,policy,regulations,statutory,tax,international', 'tax,senior', 'management,tax', 'audits,tax', 'law,transfer', 'pricing'])
# (642, ['accruals,audits,capital,coordination,deliverables,deposits,financials,forecast,landlord,landlords,metrics,reserves,reviews,scm,tax,wip,accounts', 'payable,balance', 'sheet,decision', 'making,financial', 'modelling,fixed', 'assets,real', 'estate,transfer', 'pricing'])
# (643, ['analytical,audits,capital,dashboard,deliverables,forecast,forecasting,formulation,integrity,liaison,methodology,metrics,noc,rates,statistics,tax,balance', 'sheet,cash', 'flow,financial', 'advisory,space', 'management,transfer', 'pricing'])

# %%
sample_employers = ["Capital Match Holdings Pte. Ltd.", "Comfortdelgro Corporation Limited", "Fujitsu Asia Pte Ltd", 
                     "Millennium Capital Management (Singapore) Pte. Ltd."]

# %%
def plotSamplePosts(employers, df, figsize):

    sample_employers = map(str.upper, employers)
    sample_posts = df[(df.employer_name.isin(sample_employers)) & (df.title == "Software Engineer")]
    return plotClusterDists(sample_posts, figsize)

# %%
fig = plotSamplePosts(sample_employers, df=filtered_df, figsize=(6, 8))
plt.savefig(LDA_DIR + 'fig/se_in_fin3.jpg')
plt.savefig(LDA_DIR + 'fig/se_in_fin3.pdf')
plt.show(); plt.close()

# %%
filtered_df.shape[0]

# %%
# Statistics check

# %%
posts = pd.read_csv(DATA_DIR + 'full_job_posts.csv')
print posts.shape
posts.head()

# %%
jd_df = pd.read_csv('d:/larc_projects/job_analytics/data/raw/jd.csv')
print jd_df.shape
jd_df.head()

# %%
tmp = pd.merge(posts, jd_df)
tmp = tmp.drop_duplicates()
tmp.shape

# %%
tmp = tmp.drop_duplicates(['employer_name', 'job_description_clob'])
tmp.shape
